# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
from matplotlib.pyplot import figure
from pycountry_convert import country_alpha2_to_continent_code, country_name_to_country_alpha2

# %% [markdown]
# # Reading the Data

# %%
#

# %%
#Reading the data, where unicron data is stored in df data frame.
df=pd.read_csv('https://drive.google.com/file/d/1nQQ57XLROvjj1_fKf8fLimNjI7IajHPa/view?usp=sharing')
df.shape
# Out:
# (168, 757)

# %%
#Here similarly, GDP data is stored in df1 data frame.
df1=pd.read_csv('https://drive.google.com/file/d/1V5ooloHCJsN-RNiJ4-dI9Sdp0na_1udz/view?usp=sharing')
df1.shape
# Out:
# (168, 757)

# %%
df.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="bk0LZfikxvxXHLv9dMmvLw">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>Unicorn_Companies.csv - Google Drive</title><meta property="og:title" content="Unicorn_Companies.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1nQQ57XLROvjj1_fKf8fLimNjI7IajHPa/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                               try{
# 1                                             var ja
# 2  _.ha=function(){return _.q("Safari")&&!(_.fa()...
# 3  _.la=function(a){var b=a.length;if(0<b){for(va...
# 4  ua=function(a){return Array.isArray(a)?!!(sa(a...
#
#                                                  400  \
# 0                                                NaN
# 1                                                 ra
# 2                                                NaN
# 3  d=0;d<b;d++)c[d]=a[d];return c}return[]};_.ma=...
# 4  2)};wa=function(a){return null!==a&&"object"==...
#
#                                                  500  \
# 0                                                NaN
# 1                                                 sa
# 2                                                NaN
# 3  b){Object.isFrozen(a)||(qa?a[qa]|=b:void 0!==a...
# 4                                    configurable:!1
#
#   700" nonce="bk0LZfikxvxXHLv9dMmvLw"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.u9N-W67SQ0k.L.X.O/d=0/rs=AO0039uULnLaXR2ZZIYQCTzxQzWmxYQ4NA" nonce="bk0LZfikxvxXHLv9dMmvLw"><script nonce="EjKed2CV3EdPSWy8PgmNTQ">_docs_flag_initialData={"docs-ails":"docs_cold"  \
# 0                                                NaN
# 1                                                 ua
# 2                                                NaN
# 3                                       {Rd:{value:b
# 4                                        writable:!1
#
#                                 docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd"  \
# 0                                                NaN                     NaN
# 1                                                 va                      wa
# 2                                                NaN                     NaN
# 3                                    configurable:!0             writable:!0
# 4  enumerable:!1}};_.Ba=function(a){switch(typeof...                     NaN
#
#                                          docs-shdn:0    docs-tfh:""  \
# 0                                                NaN            NaN
# 1                                                 xa             Ea
# 2                                                NaN            NaN
# 3  enumerable:!1}}))};sa=function(a){var b;qa?b=a...  1);return a};
# 4                                                NaN            NaN
#
#   info_params:{} docos-eddmh:false  ... null.192 1.59 5.2  qr 181] [[null.2  \
# 0            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 1             Fa                Da  ...      NaN  NaN NaN NaN  NaN      NaN
# 2            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 3            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 4            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
#
#   null.193 null.194  \
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
#   https://www.gstatic.com/og/_/js/k=og.qtm.en_US.C_dqw0ArTwE.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTue4GbpmaaJUr5DgiDj78EPxNS2RQ]]]]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 757 columns]

# %%
df1.head()
# Out:
#   <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="1mG2L9GA1+7BmesFgSHAig">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>csvData.csv - Google Drive</title><meta property="og:title" content="csvData.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1V5ooloHCJsN-RNiJ4-dI9Sdp0na_1udz/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300  \
# 0                                               try{
# 1                                             var ja
# 2  _.ha=function(){return _.q("Safari")&&!(_.fa()...
# 3  _.la=function(a){var b=a.length;if(0<b){for(va...
# 4  ua=function(a){return Array.isArray(a)?!!(sa(a...
#
#                                                  400  \
# 0                                                NaN
# 1                                                 ra
# 2                                                NaN
# 3  d=0;d<b;d++)c[d]=a[d];return c}return[]};_.ma=...
# 4  2)};wa=function(a){return null!==a&&"object"==...
#
#                                                  500  \
# 0                                                NaN
# 1                                                 sa
# 2                                                NaN
# 3  b){Object.isFrozen(a)||(qa?a[qa]|=b:void 0!==a...
# 4                                    configurable:!1
#
#   700" nonce="1mG2L9GA1+7BmesFgSHAig"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.u9N-W67SQ0k.L.X.O/d=0/rs=AO0039uULnLaXR2ZZIYQCTzxQzWmxYQ4NA" nonce="1mG2L9GA1+7BmesFgSHAig"><script nonce="HPXQUP2WQ3e8LOuFTxhuLg">_docs_flag_initialData={"docs-ails":"docs_warm"  \
# 0                                                NaN
# 1                                                 ua
# 2                                                NaN
# 3                                       {Rd:{value:b
# 4                                        writable:!1
#
#                                 docs-fwds:"docs_sdf" docs-crs:"docs_crs_nfd"  \
# 0                                                NaN                     NaN
# 1                                                 va                      wa
# 2                                                NaN                     NaN
# 3                                    configurable:!0             writable:!0
# 4  enumerable:!1}};_.Ba=function(a){switch(typeof...                     NaN
#
#                                          docs-shdn:0    docs-tfh:""  \
# 0                                                NaN            NaN
# 1                                                 xa             Ea
# 2                                                NaN            NaN
# 3  enumerable:!1}}))};sa=function(a){var b;qa?b=a...  1);return a};
# 4                                                NaN            NaN
#
#   info_params:{} docos-eddmh:false  ... null.192 1.59 5.2  qr 215] [[null.2  \
# 0            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 1             Fa                Da  ...      NaN  NaN NaN NaN  NaN      NaN
# 2            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 3            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
# 4            NaN               NaN  ...      NaN  NaN NaN NaN  NaN      NaN
#
#   null.193 null.194  \
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
#
#   https://www.gstatic.com/og/_/js/k=og.qtm.en_US.C_dqw0ArTwE.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTue4GbpmaaJUr5DgiDj78EPxNS2RQ]]]]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   };this.gbar_=this.gbar_||{};(function(_){var window=this;
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 757 columns]

# %% [markdown]
# # Cleaning

# %%
df1.isna().sum()
# Out:
# <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="1mG2L9GA1+7BmesFgSHAig">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>csvData.csv - Google Drive</title><meta property="og:title" content="csvData.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1V5ooloHCJsN-RNiJ4-dI9Sdp0na_1udz/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300      0
# 400                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           64
# 500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           72
# 700" nonce="1mG2L9GA1+7BmesFgSHAig"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.u9N-W67SQ0k.L.X.O/d=0/rs=AO0039uULnLaXR2ZZIYQCTzxQzWmxYQ4NA" nonce="1mG2L9GA1+7BmesFgSHAig"><script nonce="HPXQUP2WQ3e8LOuFTxhuLg">_docs_flag_initialData={"docs-ails":"docs_warm"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            92
# docs-fwds:"docs_sdf"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          97
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             ...
# [[null.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     168
# null.193                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     168
# null.194                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     168
# https://www.gstatic.com/og/_/js/k=og.qtm.en_US.C_dqw0ArTwE.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTue4GbpmaaJUr5DgiDj78EPxNS2RQ]]]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           168
# };this.gbar_=this.gbar_||{};(function(_){var window=this;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    168
# Length: 757, dtype: int64

# %%
df.isna().sum()
# Out:
# <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="bk0LZfikxvxXHLv9dMmvLw">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>Unicorn_Companies.csv - Google Drive</title><meta property="og:title" content="Unicorn_Companies.csv"><meta property="og:type" content="article"><meta property="og:site_name" content="Google Docs"><meta property="og:url" content="https://drive.google.com/file/d/1nQQ57XLROvjj1_fKf8fLimNjI7IajHPa/view?usp=sharing&amp;usp=embed_facebook"><link rel="shortcut icon" href="https://ssl.gstatic.com/images/branding/product/1x/drive_2020q4_32dp.png"><link rel="stylesheet" href="https://fonts.googleapis.com/css?family=Google+Sans:300      0
# 400                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               64
# 500                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               72
# 700" nonce="bk0LZfikxvxXHLv9dMmvLw"><link rel="stylesheet" href="https://www.gstatic.com/_/apps-fileview/_/ss/k=apps-fileview.v.u9N-W67SQ0k.L.X.O/d=0/rs=AO0039uULnLaXR2ZZIYQCTzxQzWmxYQ4NA" nonce="bk0LZfikxvxXHLv9dMmvLw"><script nonce="EjKed2CV3EdPSWy8PgmNTQ">_docs_flag_initialData={"docs-ails":"docs_cold"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                92
# docs-fwds:"docs_sdf"                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              97
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ...
# [[null.2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         168
# null.193                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         168
# null.194                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         168
# https://www.gstatic.com/og/_/js/k=og.qtm.en_US.C_dqw0ArTwE.O/rt=j/m=qabr,q_dnp,qapid/exm=qaaw,qadd,qaid,qein,qhaw,qhbr,qhch,qhga,qhid,qhin,qhpr/d=1/ed=1/rs=AA2YrTue4GbpmaaJUr5DgiDj78EPxNS2RQ]]]]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               168
# };this.gbar_=this.gbar_||{};(function(_){var window=this;                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        168
# Length: 757, dtype: int64

# %%
modify=lambda x: float(x.split('$')[1].split('B')[0])*1000000 if (x[len(x)-1]=='B') else ( float(x.split('$')[1].split('M')[0])*1000 if (x[len(x)-1]=='M') else ( 0 if (x == 'None') else float(x.split('$')[1].split('K')[0])))

#Frist we remove the $ sign form Valuation column.
df['Valuation ($B)']=[x.split('$')[1] for x in df['Valuation ($B)'].tolist()] 

#Next, we remove the $ along with its other characters like 'M','K' so on and concvert the data into 100000 format i.e 'K'.
df['Total Raised']=[modify(x) for x in df['Total Raised'].tolist()] 
df.rename({'Total Raised': 'Total Raised ($K)'}, axis=1, inplace=True)

#Convert the Portfolio Exits, Investors Count and Deal Terms to 0 if its none.
df['Portfolio Exits']=[0  if(x=='None') else x for x in df['Portfolio Exits'].tolist()]
df['Investors Count']=[0  if(x=='None') else x for x in df['Investors Count'].tolist()]
df['Deal Terms']=[0  if(x=='None') else x for x in df['Deal Terms'].tolist()]

#Finally, we convert the numeric columns to int and float data columns, i.e into its respective data type and then we convert 
#these columns to numeric data set.
df.astype({'Valuation ($B)':float,'Total Raised ($K)':float,'Investors Count':int,'Deal Terms':int,'Portfolio Exits':int})
df[['Valuation ($B)','Total Raised ($K)','Investors Count','Deal Terms','Portfolio Exits']]=df[['Valuation ($B)','Total Raised ($K)','Investors Count','Deal Terms','Portfolio Exits']].apply(pd.to_numeric)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Valuation ($B)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-4e0b538a8120> in <module>
#       2
#       3 #Frist we remove the $ sign form Valuation column.
# ----> 4 df['Valuation ($B)']=[x.split('$')[1] for x in df['Valuation ($B)'].tolist()]
#       5
#       6 #Next, we remove the $ along with its other characters like 'M','K' so on and concvert the data into 100000 format i.e 'K'.
#
# c:\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# c:\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
# -> 2900                 raise KeyError(key) from err
#    2901
#    2902         if tolerance is not None:
#
# KeyError: 'Valuation ($B)'

# %% [markdown]
# # **Exploratory Data Analysis**

# %% [markdown]
# #### Overview of data types of each columns in the dataframe

# %%
df.dtypes

# %%
df1.dtypes

# %% [markdown]
# #### Show numeric data types in dataframe

# %%
df.select_dtypes(include=['number'])

# %%
df1.select_dtypes(include=['number'])

# %% [markdown]
# # Question and answers along with their visualizations

# %% [markdown]
# ### Q1) Are the top 10 countries with the highest GDP, the top 10 countries with the most number of unicorns?

# %%
#First we get the top 10 countries with higest GDP, next we get top 10 countries with most number of unicorns.
df10=df1.head(10)
df10.index=df10['country'].tolist()
df11=df.groupby('Country').size().reset_index(name='counts').sort_values('counts', ascending=False).head(10)
df10

# %%
#Modifying the font of the graph.
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 10}
matplotlib.rc('font', **font)

#First we get the top 10 countries with higest GDP graph.
fig = plt.figure(figsize = (12, 5))
plt.bar(df10['country'],df10['imfGDP'])
plt.xlabel("Countries")
plt.ylabel("IMF Gross Domestic Product")
plt.title("Top 10 countries with higest GDPs")
plt.show()

#Next we get the top 10 countries with most number of unicorns.
fig = plt.figure(figsize = (12, 5))
plt.bar(df11['Country'],df11['counts'])
plt.xlabel("Countries")
plt.ylabel("Number of Unicorns")
plt.title("Top 10 countries with most number of Unicorns")
plt.show()

# %% [markdown]
# ##### False, not same countries
# We can see from the above graph top 10 countries with the highest GDP are not the top 10 countries with the most number of unicorns. The list is same till China, then the diffrence begins.
# So the answer is No.

# %% [markdown]
# ### Q2) If the first question is false, the countries with an exception are more or less than 3 in number?

# %%
#We then modify the index of the graphs.
df10=df10.reset_index()
df10['pos_gdp']=range(1,len(df10)+1)
df11['pos_uniocorns']=range(1,len(df11)+1)

# %%
#Next we rename the column of country in unicon data so that we can merge the data. Next we merge both data based on the 
#country and change new data set index to country.
df11.rename(columns = {'Country':'country'}, inplace = True)
result = pd.merge(df10,df11, how="outer", on='country')
result.index=result['country'].tolist()

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 24}
matplotlib.rc('font', **font)

#Finally we plot the data with the combined data.
fig = plt.figure()
result[['pos_gdp','pos_uniocorns']].plot.bar(figsize = (50, 10))
plt.xlabel("Countries")
plt.ylabel("Positions")
plt.title("Top 10 countries based on GDP and number of unicorns")
plt.show()

# %% [markdown]
# #### Greater than 3 countries
# We can see from the above graph that countries like Japan and Italy have GDP, in top 10 but is not in the top 10 with highest number of unicorns. Vice versa for Isreal and South Korea.

# %% [markdown]
# ### Q3) Do china and USA have half of all unicorns in the world?

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 10}
matplotlib.rc('font', **font)

# We first count the number of unicorns in each country and place it in counts column.
df12=df.groupby('Country').size().reset_index(name='counts').sort_values('counts', ascending=False)
df12.index=range(1,len(df12)+1)

#Next we find the percentage of the unicorns present in each country and print it with the numbers designated to the country.
df12['percentage'] =round(df12['counts'] / df12['counts'].sum() * 100,2)
countries=df12[['Country','percentage']].to_dict()
print(countries['Country'],'\n\n',countries['percentage'])

#Finally we display the graph based on the count of unicorns.
df12['counts'].plot(kind='pie', y='votes_of_each_class',figsize = (70, 12))
plt.title("Countries with their respective share in unicorns of the world")

# %% [markdown]
# #### True
# In fact USA itself has more than half number of Unicrons. Combined USA and China have 67.89 i.e two third of all the unicorn companies present in the world.

# %% [markdown]
# ### Q4) There is no company with more than 10 billion  in valuation with less than 500 million  in total funding. Is it true?

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 24}
matplotlib.rc('font', **font)
plt.figure(figsize=(30,10))

#We first find the companies with valuation more than 10 billion.
df13=df[df['Valuation ($B)']>10]

#Next we place the color as red for companies which reaised less than 500 million in funding i.e total funding raised.
condition= ['blue' if (x>=500000.0) else 'red' for x in df13['Total Raised ($K)']]

#We then convert the funding money format from 100000 i.e (K) to billion.
df13.index=df13['Company'].tolist()
df13['Total Raised ($K)']=[x/1000000 for x in df13['Total Raised ($K)']]

#Next we plot the graph by combining the valuation and funding graph with funding data as green.
plt.figure(figsize=(50,30)) 
ax=df13['Valuation ($B)'].plot.bar(color=condition)
df13['Total Raised ($K)'].plot.bar(color='green',ax=ax)

#We label the graph with respective names.
plt.xlabel("Companies")
plt.ylabel("Valuation in Billions$")
plt.title("Companies with 10$ Billion valuation and with fundings less or greater than 500$ Million")

red = mpatches.Patch(color='#FF0000', label='Lower funding than 500 Million')
blue = mpatches.Patch(color='#0000FF', label='Higher or same funding as 500 Million')
plt.legend(handles=[blue,red])
plt.show()

# %% [markdown]
# #### False
# We can see from the graph that the comapanies like Miro,Ripple,OpenSea and so on have less that half a billion in funding but are valued more than 10$ billion.

# %% [markdown]
# ### Q5) Beijing has more unicorns between 2018 and 2020 than San Francisco in the same period. Is it the other way around?

# %%
#We first get the data joined and city data from the main data set.
df14=df[['Date Joined','City']]

#We next get the joined year from joined date.
df14['Joined Year']=[int(pd.to_datetime(x).year) for x in df14['Date Joined']]

#Next, we get the data of cities we require i.e Beijing and San Francisco.
df14=df14[df14['City'].isin(['Beijing','San Francisco'])].sort_values(['Joined Year'])

#Then we find the  number of unicorns of both the cities in all the years they produces unicorns. 
df14=df14.groupby(['Joined Year','City']).size().reset_index(name='unicorns')

#Then we find the number of unicrons for every 3 year duration in both the cities into a list of list.
Range_unicorns=[[df14[(df14['Joined Year'].isin([x,x+1,x+2]))&(df14['City']=='Beijing')]['unicorns'].sum(),
                df14[(df14['Joined Year'].isin([x,x+1,x+2]))&(df14['City']=='San Francisco')]['unicorns'].sum(),
                str(x)+'-'+str(x+2)] for x in range(2012,2022,3)]

#We then convert the list of list to data frame.
df15= pd.DataFrame(Range_unicorns, columns = ['Beijing','San Francisco','Year duration'])

#We finally place the years subset to the index of the data set.
df15.index=df15['Year duration'].tolist()
df15

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)

#We finally plot the graph based on the data.
df15.plot.bar(figsize=(50,25))

plt.xlabel("Years")
plt.ylabel("Number of uicorns")
plt.title("Number of uniorns in Beijing and San Francisco over the years")

plt.legend(['Beijing','San Francisco'])
plt.show()

# %% [markdown]
# #### False
# We can see from the above graph that number of unicorns in San Francisco(39) are more than that of Beijing(25) in the duration between 2018 to 2020. How ever we can see that there are some cases like 2015-2017 where the case was reversed.

# %% [markdown]
# ### Q6) China and India combined have more than 60% of all the Ed-tech companies present in the world. Is it true?

# %%
#First we find the data set of all the Edtech companies, then we find which country has how many number of unicorns and 
#we sort it.
df16=df[df['Industry']=='Edtech'].groupby('Country').size().reset_index(name='counts').sort_values('counts', ascending=False)

#Next we change the index to the countries we considering.
df16.index=df16['Country'].tolist()

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 20}
matplotlib.rc('font', **font)

#Next we find the percentage of Ed tech unicorns each country has.
df16['percentage'] =round(df16['counts'] / df16['counts'].sum() * 100,2)
print(df16['percentage'])

#Finally we plot graph based on our current data.
df16['percentage'].plot(kind='pie', y='votes_of_each_class',figsize = (70, 12))
plt.title("Countries with their respective share of unicorns in Edtech space.")
plt.ylabel("")
plt.show()

# %% [markdown]
# #### True
# We can see from the graph that China and India combined have 64.29% i.e more than 60% of the total number of unicorns in Edtech Industry.

# %% [markdown]
# ### Q7) Europe has more number acquired unicorns than there are unicorns in IPO stage in Asia, is it True?

# %%
#Frst we get the country name and financial stage data from the main data set. Along with removing all the unicorns which are 
#still working independently, which is represented as 'None' in dataset.
df18=df[['Country','Financial Stage']][df['Financial Stage']!='None']

#Next we find the continent of the country using 'pycountry_convert' package. Here we first convert the country name to a code 
#and then convert the code to the continent code.
df18['continent'] =  [country_alpha2_to_continent_code(country_name_to_country_alpha2(x)) for x in df18['Country']]

#Then we find the total number of countries in cretain financial stage, for each contient.
eu=df18[df18['continent']=='EU'].groupby('Financial Stage').size().reset_index(name='eu')
asia=df18[df18['continent']=='AS'].groupby('Financial Stage').size().reset_index(name='asia')

#Next, we combine both the contients data and create a new data set.
df18=pd.merge(eu,asia,on='Financial Stage',how='outer')
df18.index=df18['Financial Stage'].tolist()
df18

# %%
font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 22}
matplotlib.rc('font', **font)

#Finally, we plot the graph from the combined data.
df18.plot.bar(figsize=(50,25))

plt.xlabel("Financial Stage of the company in that continet")
plt.ylabel("Number of uicorns")
plt.title("Number of unicorns with respect to their Financial Stage in Europe and Asia Contients")

plt.legend(['EU','Asia'])
plt.show()

# %% [markdown]
# #### True
# We can see from the graph that there are more number of unicrons which are in IPO stage in Asia than unicorns which are aquired in Europe.

# %% [markdown]
# ### Q8) From the top 50 unicorns, Sequoia Capital has more investments than Softbank Group. Or is it the other way around?

# %%
#First we get the data of top 50 unicorns.
df19=df.head(50)

#Next we get all the investors present in the top 50 unicorns into a list of each compnay and next int a single list with 
#duplicate values in it. We also remove the space in front of the text to remove the distinction between the investor names.
investors=[ x.split(',') if x!='None' else [] for x in df19['Select Inverstors'].tolist()]
investors=[j[1:] if(j[0]==' ') else j for i in investors for j in i]

#Next we find how many time the invsetors name is being repeated in the list and get the investments it made in total.
df19=pd.DataFrame(investors,columns=['investors'])
df19=df19.groupby('investors').size().reset_index(name='counts').sort_values('counts', ascending=False)
df19

# %%
#We next find the data of our required investors i.e Sequoia Capital and Softbank Group.
required_investors=[x if('Sequoia Capital'in x or 'Softbank Group' in x) else '' for x in df19['investors'].tolist()]
df19=df19[df19['investors'].isin(required_investors)]
df19.index=df19['investors'].tolist()

#We place the Softbank Group data as green and Sequoia Capital data as blue.
condition=['blue' if ('Sequoia Capital' in x) else 'green' for x in df19['investors'].tolist()]

# %%
fig = plt.figure(figsize = (40, 20))

#We finally plot the data set we obtained.
df19['counts'].plot.bar(color=condition)
plt.xlabel("Investors")
plt.ylabel("Total number of Investemts")
plt.title("Sequoia Capital and Softbank Groups total number of investments")
plt.show()

# %% [markdown]
# #### True
# We can see from the graph that Sequoia Capital China itself has more number of investments in top 50 unicorns than all of Softbank investments.

# %% [markdown]
# ### Q9) Indonesia has less number of investors than the 2 countries, which one position more and less in a list based unicorns count of that country. Is it true?

# %%
#First we get the data of number of unicorns in each country.
df20=df.groupby('Country').size().reset_index(name='counts').sort_values('counts', ascending=False)
df20.index=df20['Country'].tolist()

#Then we place the Indonesia data in red, its adjacent data as green and the remaining dat as blue.
condition =['red' if(df20['Country'].iloc[x] == 'Indonesia') else('green' if(df20['Country'].iloc[x-1] == 'Indonesia' or df20['Country'].iloc[x+1] == 'Indonesia') else 'blue') for x in range(2,len(df20)-1)]

#Then we plot the graph with number of unicorns in each country.
fig = plt.figure(figsize = (40, 20))
df20['counts'].plot.bar(color=['blue','blue']+condition)
plt.xlabel("Countries")
plt.ylabel("Number of Unicorns")
plt.title("Countries with number of unicorns with Indonesia and its adjecent countries")

red = mpatches.Patch(color='#FF0000', label='Indonesia')
blue = mpatches.Patch(color='#0000FF', label='Countries')
green = mpatches.Patch(color='#008000', label='Adjacent countries to Indonesia')
plt.legend(handles=[blue,red,green])

plt.show()

# %%
#Here we first get the country and investors data. Then find the number of investors in each country.
df21=df[['Country','Select Inverstors']]
df21['Select Inverstors']=[ x.split(',') if x!='None' else [] for x in df21['Select Inverstors']]
df21=df21.groupby('Country').agg({'Select Inverstors': 'sum'}).reset_index()
df21['Select Inverstors']=[len(list(set(x))) for x in df21['Select Inverstors']]

#Next we combine the data with unicorn count and investor count based on the country into a single data set.
#Next we sort the graph based on the unicorn count. 
df22=pd.merge(df20,df21,on='Country').sort_values('counts', ascending=False)
df22.rename(columns={'counts': 'unicorns', 'Select Inverstors': 'Investors'}, inplace=True)
df22

# %%
#Finally we plot a graph with the inverstor count data in a unicorn count order for each country.
fig = plt.figure(figsize = (40, 20))
df22.index=df22['Country'].tolist()
df22['Investors'].plot.bar(color=['blue','blue']+condition)
plt.xlabel("Countries")
plt.ylabel("Number of Investors")
plt.title("Countries with number of Investors investing its unicorns with Indonesia and its adjecent countries")

red = mpatches.Patch(color='#FF0000', label='Indonesia')
blue = mpatches.Patch(color='#0000FF', label='Countries')
green = mpatches.Patch(color='#008000', label='Adjacent countries to Indonesia')
plt.legend(handles=[blue,red,green])

plt.show()

# %% [markdown]
# #### False
# We can see from the graph that Indonesia has more number of investors that singapore and Australia, infact Singapore unicorn companies has no investors.
